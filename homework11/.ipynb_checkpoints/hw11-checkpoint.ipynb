# %% [markdown]
# # HW 11 - Fall Semester Review
# ULAB - Physics and Astronomy Division \
# Due **Sunday, February 2nd, 2025 at 11:59pm** on Gradescope
#
# To prepare for next week’s homework, where we’ll explore exoplanets using **pandas**, this assignment will review fundamental Python concepts within the same theme.

# %% [markdown]
# ## 0 Academic Integrity
# Please type the following message in the cell below as a comment. Sign with your name.
#
# ------
# **I certify that I did not use AI tools, such as ChatGPT, to generate or write code for this assignment. All work submitted is my own and reflects my understanding of the material.**
#
# ------

# %%
# Ylann Bouis

# %% [markdown]
# ## 1 Functions
# **Orbital Periods and Kepler's Third Law** \
# Kepler's Third Law states that the square of the orbital period $T$ (in years) of a planet is proportional to the cube of the semi-major axis $a$ (in astronomical units, AU):
#
# $$
# T^2 = a^3
# $$
#
# Write a **function** that calculates the orbital period $T$ given the semi-major axis $a$. (So, you can assume that $T = \sqrt{a^3}$.)

# %%
# Your code here (WITHOUT NUMPY! or any other modules/libraries/packages)
def period(a):
    # Takes in a semi-major axis a and returns the orbital period T
    return a**(3/2)

# %% [markdown]
# Call your function with the following values:
# * `planet_a` $ = 0.5\,\text{AU}$
# * `planet_b` $ = 1.0\,\text{AU}$
# * `planet_c` $ = 1.5\,\text{AU}$

# %%
# Your code here
planet_a = 0.5
planet_b = 1
planet_c = 1.5
print(period(planet_a))
print(period(planet_b))
print(period(planet_c))
# Out:
# 0.3535533905932738
# 1.0
# 1.8371173070873836

# %% [markdown]
# Import `numpy` in the cell below.

# %%
import numpy as np

# %% [markdown]
# How many times do you need to call numpy in a jupyter notebook? Why?

# %%
# Your comment (2 sentences)
# You only need to import numpy once in a Jupyter notebook. This is because once you run the import statement, jupyter notebook remembers that you imported it, so you don't have to do it again.

# %% [markdown]
# Rewrite your **function** from above with a `numpy` function.

# %%
# Your code here
def period2(a):
    # Takes a semi-major axis a and returns the orbital period T using numpy
    return np.power(a, 3)

# %% [markdown]
# Import the `time` package in the cell below.

# %%
# Your code here
import time as t

# %% [markdown]
# Call both of your functions in the cell below with ($a$ = 5). Time how long it takes each of your functions to run. **DO NOT REWRITE THEM!**

# %%
# Your code here
a = 5
start1 = t.perf_counter()
period(a)
end1 = t.perf_counter()
start2 = t.perf_counter()
period2(a)
end2 = t.perf_counter()
print(end1 - start1, end2 - start2)
# Out:
# 6.669998401775956e-05 0.00037429999792948365

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
# The first function (without numpy) was faster. It's faster because it's a built-in function so it doesn't need any extra code like numpy. Numpy functions may be slower with only one input.

# %% [markdown]
# Define a **list** in the cell below that contains a least 1,000,000 semi-major axis values.

# %%
a_list = [axis for axis in range(0,1000000)]

# %% [markdown]
# With a **for** loop. Time each of your functions again with this new list.

# %%
start1 = t.perf_counter()
for a in a_list:
    period(a)
end1 = t.perf_counter()
start2 = t.perf_counter()
for a in a_list:
    period2(a)
end2 = t.perf_counter()
print(end1 - start1, end2 - start2)
# Out:
# 0.2620038999884855 1.057861999986926

# %% [markdown]
# Which function is faster? Why is it faster? What does that tell you about numpy functions?

# %%
# Still, the first function (without numpy) was faster. It's faster because it's a built-in function so it doesn't need any extra code like numpy. Numpy functions may still be slower when applied to for loops.

# %% [markdown]
# ## 2 Indexing + Conditionals
#
# You are provided with a list of exoplanet radii (in Earth radii) and their equilibrium temperatures (in Kelvin):
#
# `radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]` \
# `temperatures = [300, 400, 350, 280, 500, 450]`

# %% [markdown]
# Write a loop to filter and print the radii of planets with temperatures below 350 K.

# %%
radii = [1.2, 0.8, 1.5, 2.0, 1.0, 0.6]
temperatures = [300, 400, 350, 280, 500, 450]
for i in range(len(radii)):
    if temperatures[i] < 350:
        print(radii[i])
# Out:
# 1.2
# 2.0

# %% [markdown]
# Use list slicing to extract and print the radii of the first three planets.

# %%
# Your code here
print(radii[0:3])
# Out:
# [1.2, 0.8, 1.5]

# %% [markdown]
# Turn the radii and temperatures data into a dictionary.

# %%
radii_temp_dict = {
    1.2: 300,
    0.8: 400,
    1.5: 350,
    2.0: 280,
    1.0: 500,
    0.6: 450
}

# %% [markdown]
# Give each of the planets in your dictionary a name.

# %%
# Your code here
planets_dict = {
    "Mercury2": {'radius': 1.2, 'temp': 300},
    "Venus2": {'radius': 0.8, 'temp': 400},
    "Earth2": {'radius': 1.5, 'temp': 350},
    "Mars2": {'radius': 2.0, 'temp': 280},
    "Jupiter2": {'radius': 1.0, 'temp': 500},
    "Saturn2": {'radius': 0.6, 'temp': 450}
}

# %% [markdown]
# Create a new dictionary of planets with radii between 1.0 and 2.0 Earth radii (inclusive).

# %%
# Your code here
planets_dict2 = {
    "Mercury2": {'radius': 1.2, 'temp': 300},
    "Earth2": {'radius': 1.5, 'temp': 350},
    "Mars2": {'radius': 2.0, 'temp': 280},
    "Jupiter2": {'radius': 1.0, 'temp': 500}
}

# %% [markdown]
# ## 3 NumPy
# With your 1,000,000 semi-major axes list from Problem 1, convert it to a `numpy` array.

# %%
# Your code here
a_list_np = np.array(a_list)

# %% [markdown]
# With `numpy` find the mean, median, minimum and maximum.

# %%
# Your code here
print(np.mean(a_list_np))
print(np.median(a_list_np))
print(np.min(a_list_np))
print(np.max(a_list_np))
# Out:
# 499999.5
# 499999.5
# 0
# 999999

# %% [markdown]
# Google another `numpy` function and apply it to your data. Explain what it does in a comment.

# %%
# This calculates the standard deviation (population) of the list
print(np.std(a_list_np))
# Out:
# 288675.1345946685

# %% [markdown]
# Turn the radii and temperatures from Problem 2 into a multi-dimensional array.

# %%
# Your code here
radii_temps = np.array([radii, temperatures])

# %% [markdown]
# Use a for loop to print the value on the second row, third column.

# %%
# Your code here
for i in range(len(radii_temps)):
    for j in range(len(radii_temps[i])):
        if i == 1 and j == 2:
            print(radii_temps[i][j])
# Out:
# 350.0

# %% [markdown]
# Use a `numpy` arrive to print the value on the second row, third column.

# %%
# Your code here
print(radii_temps[1][2])
# Out:
# 350.0

# %% [markdown]
# ## 4 Plotting
# Create a scatter plot of the following semi-major axes (x-axis) vs. orbital periods (y-axis). Label the axes, add a legend and add a title: "Orbital Periods of Exoplanets."
#
# `semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]`

# %%
# Your code here
semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]
periods = [period(a) for a in semi_major_axes]
plt.scatter(semi_major_axes, periods, label="semi_major_axis vs periods", color="blue")
plt.title("semi major axes vs orbital periods", fontdict={'fontsize': 8})
plt.xlabel("Semi major axis", fontdict={'fontsize': 8})
plt.ylabel("Orbital Periods", fontdict={'fontsize': 8})
plt.legend()
plt.show()

# %% [markdown]
# Create a bar plot of planet radii vs. their equilibrium temperatures. Label the axes, add a legend and add a title: "Equilibrium Temperatures vs. Radii."

# %%
# Your code here
semi_major_axes = [0.5, 1.0, 2.0, 1.5, 1.2, 0.8]
periods = [period(a) for a in semi_major_axes]
plt.bar(radii, periods, label="Equilibrium Temperatures vs. Radii", color="blue")
plt.title("Equilibrium Temperatures vs. Radii", fontdict={'fontsize': 8})
plt.xlabel("Radii", fontdict={'fontsize': 8})
plt.ylabel("Temperatures", fontdict={'fontsize': 8})
plt.legend()
plt.show()

# %% [markdown]
# Put the scatter plot and bar plot on the same figure (horizonatally).

# %%
# Your code here
fig, (ax1, ax2) = plt.subplots(1, 2)
ax1.scatter(semi_major_axes, periods, label="semi_major_axis vs periods", color="blue")
ax2.bar(radii, periods, label="Equilibrium Temperatures vs. Radii", color="blue")
# Out:
# <BarContainer object of 6 artists>

# %% [markdown]
# ## 5 Modules
# Choose a function from this homework and put it into a module. Import the module with the function below. Make sure to show the output.

# %%
import my_module3

# %%
print(my_module3.period3(2))
# Out:
# 2.8284271247461903
